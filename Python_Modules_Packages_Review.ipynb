# %% [markdown]
# ### Python Modules, Packages Review
# - 02.05.2022
# - C.Arellano

# %% [markdown]
# ## min(), max(), sum()

# %%
int_list = [1,2,3,4]

# %%
print(f'min: {min(int_list)}')
# Out:
# min: 1

# %%
print(f'max: {max(int_list)}')
# Out:
# max: 4

# %%
print(f'sum: {sum(int_list)}')
# Out:
# sum: 10

# %%
int_list2 = [-1,-3,10, 50]

# %%
print(f'abs: {abs(int_list2[0])}')
# Out:
# abs: 1

# %% [markdown]
# ## len() , sorted() : list, tuple, dictionary

# %%
mylist = [1,30, -1000]
mytuple = (100, 2, 35)
mydict = {
    'Name': 'Zara',
    'Age': 7,
    'Class': 'First'}
mydict2 = {
    'a' : 56,
    'b' : 70,
    'c' : -59,
    'd' : 900 }

# %%
len(mylist)
# Out:
# 3

# %%
sorted(mylist)
# Out:
# [-1000, 1, 30]

# %%
len(mytuple)
# Out:
# 3

# %%
sorted(mytuple)
# Out:
# [2, 35, 100]

# %%
len(mydict)
# Out:
# 3

# %%
sorted(mydict)
# Out:
# ['Age', 'Class', 'Name']

# %%
len(mydict2)
# Out:
# 3

# %%
sorted(mydict2.values())
# Out:
# [-59, 56, 70]

# %% [markdown]
# ## dir() , globals(), locals(), vars()

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_15',
#  '_16',
#  '_17',
#  '_19',
#  '_21',
#  '_22',
#  '_24',
#  '_25',
#  '_27',
#  '_30',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'int_list',
#  'int_list2',
#  'mydict',
#  'mydict2',
#  'mylist',
#  'mytuple',
#  'quit']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "print(f'min list: {min(int_list)}')",
#   'int_list = [1,2,3,4]',
#   "print(f'min list: {min(int_list)}')",
#   "print(f'min: {min(int_list)}')",
#   "print(f'max list: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'sum: {sum(int_list)}')",
#   "print(f'abs: {abs(int_list2)}')",
#   'int_list2 = [-1,-3,10, 50]',
#   "print(f'abs: {abs(int_list2)}')",
#   "print(f'abs: {abs(int_list2[0])}')",
#   "mylist = [1,30, -1000]\nmytuple = (1, 2, 3)\nmydict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}",
#   'len(mylist)',
#   'len(mytuple)',
#   'len(mydict)',
#   'sort(mydict)',
#   'sorted(mydict)',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "print(f'min list: {min(int_list)}')",
#   'int_list = [1,2,3,4]',
#   "print(f'min list: {min(int_list)}')",
#   "print(f'min: {min(int_list)}')",
#   "print(f'max list: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'sum: {sum(int_list)}')",
#   "print(f'abs: {abs(int_list2)}')",
#   'int_list2 = [-1,-3,10, 50]',
#   "print(f'abs: {abs(int_list2)}')",
#   "print(f'abs: {abs(int_list2[0])}')",
#   "mylist = [1,30, -1000]\nmytuple = (1, 2, 3)\nmydict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}",
#   'len(mylist)',
#   'len(mytuple)',
#   'len(mydict)',
#   'sort(mydict)',
#   'sorted(mydict)',
# ...

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "print(f'min list: {min(int_list)}')",
#   'int_list = [1,2,3,4]',
#   "print(f'min list: {min(int_list)}')",
#   "print(f'min: {min(int_list)}')",
#   "print(f'max list: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'max: {max(int_list)}')",
#   "print(f'sum: {sum(int_list)}')",
#   "print(f'abs: {abs(int_list2)}')",
#   'int_list2 = [-1,-3,10, 50]',
#   "print(f'abs: {abs(int_list2)}')",
#   "print(f'abs: {abs(int_list2[0])}')",
#   "mylist = [1,30, -1000]\nmytuple = (1, 2, 3)\nmydict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}",
#   'len(mylist)',
#   'len(mytuple)',
#   'len(mydict)',
#   'sort(mydict)',
#   'sorted(mydict)',
# ...

# %%
test = dir()
for i in test:
    print(i)
# Out:
# In
# Out
# _
# _15
# _16
# _17
# _19
# _21
# _22
# _24
# _25
# _27
# _30
# _31
# _32
# _33
# _34
# __
# ___
# __builtin__
# __builtins__
# __doc__
# __loader__
# __name__
# __package__
# __spec__
# _dh
# _i
# _i1
# _i10
# _i11
# _i12
# _i13
# _i14
# _i15
# _i16
# _i17
# _i18
# _i19
# _i2
# _i20
# _i21
# _i22
# _i23
# _i24
# _i25
# _i26
# _i27
# _i28
# _i29
# _i3
# _i30
# _i31
# _i32
# _i33
# _i34
# _i35
# _i36
# _i4
# _i5
# _i6
# _i7
# _i8
# _i9
# _ih
# _ii
# _iii
# _oh
# exit
# get_ipython
# int_list
# int_list2
# mydict
# mydict2
# mylist
# mytuple
# quit

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
#look through

import os
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
# ...

# %% [markdown]
# ## Python  Standard Library

# %% [markdown]
# ## sys

# %%
import sys

# %%
sys.version #python version
# Out:
# '3.7.11 [MSC v.1927 64 bit (AMD64)]'

# %%
sys.modules  #modules and where they are located
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  'encodings': <module 'encodings' from 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\encodings\\__init__.py'>,
#  'codecs': <module 'codecs' from 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
# ...

# %%
sys.path
# Out:
# ['C:\\Users\\s1085509',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python37.zip',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3',
#  '',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\future-0.18.2-py3.7.egg',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pytz-2020.1-py3.7.egg',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32_ctypes-0.2.0-py3.7.egg',
# ...

# %% [markdown]
# ## os and os.path

# %%
import os

# %%
here_i_am = os.getcwd()
print(here_i_am)
# Out:
# C:\Users\s1085509

# %%
os.path.join(here_i_am, 'test.py') # append to the file path
# Out:
# 'C:\\Users\\s1085509\\test.py'

# %%
os.path.isdir(here_i_am)   #verify if in directory
# Out:
# True

# %%
os.path.dirname(here_i_am)
# Out:
# 'C:\\Users'

# %%
os.path.basename(here_i_am)
# Out:
# 's1085509'

# %% [markdown]
# ## math

# %%
import math

# %%
pi = math.pi
print(f'pi: {pi}')
# Out:
# pi: 3.141592653589793

# %% [markdown]
# ## glob

# %%
## when finding files along paths

# %% [markdown]
# ## re

# %%
# regular expression for advanced string processing
# alt: regex

# %% [markdown]
# ## urllib

# %%
# for HTTP requests
# try: urllib3, request

# %% [markdown]
# ## datetime

# %%
# manipulate date and time
# alternative: dateutil, calendar, time, zoneinfo

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 2, 11, 30, 17, 1132)

# %%
print(datetime.datetime.now())
# Out:
# 2022-05-02 11:30:55.778668

# %% [markdown]
# ## pprint

# %%
# define how things will be printed
# 'pretty print'

# %% [markdown]
# ## logging

# %%
# keep track of errors or messages during execution

# %% [markdown]
# ## xml.etree.ElementTree

# %%
# for parsing and creating XML

# %% [markdown]
# ## pickle

# %%
# python passing objects

# %% [markdown]
# ## argparse

# %%
# when need user input
# alt: click

# %% [markdown]
# ## colorsys

# %%
# rgb to HSV color space

# %%
import colorsys

# %%
# colorsys.rgb_to_hsv(r, g ,b)

r = 0.2
g = 0.4
b = 0.4

colorsys.rgb_to_hsv(r, g ,b)
# Out:
# (0.5, 0.5, 0.4)

# %% [markdown]
# ### others
# - json
# - csv
# - tkinter
# - subprocess
# - zipfile
# - uuid
